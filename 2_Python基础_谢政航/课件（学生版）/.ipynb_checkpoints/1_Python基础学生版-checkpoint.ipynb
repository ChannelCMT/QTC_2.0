# %% [markdown]
# ## Python基础语法

# %% [markdown]
# ### 1、交互式:
#
# 命令逐条运行
#
# 交互式编程不需要创建脚本文件，是通过 Python 解释器的交互模式进来编写代码。

# %%
#

# %% [markdown]
# ### 2、脚本式:
#
# 一次性全部运行
#
# 通过脚本参数调用解释器开始执行脚本，直到脚本执行完毕。当脚本执行完成后，解释器不再有效。

# %%
#

# %% [markdown]
# ### 3、代码缩进问题:
#
# 缩进替代({})
#
# 学习Python与其他语言最大的区别就是，Python的代码块不使用大括号（{}）来控制类，函数以及其他逻辑判断。
# python最具特色的就是用缩进来写模块。

# %% [markdown]
# ### 代码缩进（错误）

# %%
price = 1
if price>0:
    print ('True')
        print ('price is greater than 0')
        # 没有严格缩进，在执行时会报错
else:
    print ("False")
# Out:
#   File "<ipython-input-3-95ffcc1a2fae>", line 4
#     print ('price is greater than 0')
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ### 代码缩进（正确）

# %%
#

# %% [markdown]
# ### 4、注释代码
#
# 单行注释用 # 开头
#
# 多行注释用三个引号(''')
#
# 代码注释有一个功能在于可以在写代码时跳过不想运行的行

# %%
# 世界你好
# print('hello world')

# %%
"""
世界你好
print('hello world')
print('all in')
"""

print('all in')
# Out:
# all in

# %% [markdown]
# ## 5、报错处理

# %% [markdown]
# ### 5.1定位与调试（第几行什么错怎么改）
# 以下报错代码显示第四行出现错误，是缩进错误。

# %%
price = 1
if price>0:
        print ('True')
        print (price is greater than 0)
else:
    print "False"
# Out:
#   File "<ipython-input-7-1d2f1bbcc104>", line 4
#     print (price is greater than 0)
#                                ^
# SyntaxError: invalid syntax

# %% [markdown]
# 以下报错代码显示第六行出现错误，是少了括号。

# %%
price=1
if price>0:
        print ('True')
        print ('price is greater than 0')
else:
    print "False"
# Out:
#   File "<ipython-input-8-cf69990590e3>", line 6
#     print "False"
#                 ^
# SyntaxError: Missing parentheses in call to 'print'

# %% [markdown]
# 正确修改后的代码

# %%
#

# %% [markdown]
# ### 5.2 利用try/except来检查代码
#
# 捕捉异常可以使用try/except语句。
#
# try/except语句用来检测try语句块中的错误，从而让except语句捕获异常信息并处理。
#
# 如果你不想在异常发生时结束你的程序，只需在try里捕获它。

# %% [markdown]
# try:
#
#     正常的操作
#    ......................
#
# except:
#
#     发生异常，执行这块代码
#    ......................
#
# else:
#
#     如果没有异常执行这块代码

# %% [markdown]
# ### 考虑这个情境，我们现在要向程序中输入一个价格，为检查其有效性编写以下代码

# %%
# 定义函数
def test_price(price):
    return int(price)
# 调用函数
test_price("xyz")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-33744945d97f> in <module>()
#       3     return int(price)
#       4 # 调用函数
# ----> 5 test_price("xyz")
#
# <ipython-input-10-33744945d97f> in test_price(price)
#       1 # 定义函数
#       2 def test_price(price):
# ----> 3     return int(price)
#       4 # 调用函数
#       5 test_price("xyz")
#
# ValueError: invalid literal for int() with base 10: 'xyz'

# %%
def test_price(price):
    try:
        p = int(price)
    except ValueError:
        print("参数不是数字")
    else:
        print(p+100)
        
test_price("z66")
# Out:
# 参数不是数字

# %% [markdown]
# ### 附：所有错误类型以及继承关系见https://docs.python.org/3/library/exceptions.html#exception-hierarchy

# %% [markdown]
# ## raise
# 使用raise语句自己触发异常

# %%
def check_price(price):
    if price < 0:
        raise Exception("Invalid price!", price)# 触发异常后，后面的代码就不会再执行

# %%
try:
    check_price(-1)
    print('right')
    #触发异常
except Exception as e:
    print (e)
else:
    print ('can_trade')
# Out:
# ('Invalid price!', -1)

# %% [markdown]
# ### 关于异常调试的课堂练习
# 运行下面的代码，根据异常信息进行分析，定位出错误源头，并修复：

# %%
from functools import reduce

def str2num(s):
    return int(s)

def calc(exp):
    ss = exp.split('+')
    ns = map(str2num, ss)
    return reduce(lambda acc, x: acc + x, ns)

def main():
    r = calc('100 + 200 + 345')
    print('100 + 200 + 345 =', r)
    r = calc('99 + 88 + 7.6')
    print('99 + 88 + 7.6 =', r)

main()
# Out:
# 100 + 200 + 345 = 645
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-74ce84318ba9> in <module>()
#      15     print('99 + 88 + 7.6 =', r)
#      16
# ---> 17 main()
#
# <ipython-input-14-74ce84318ba9> in main()
#      12     r = calc('100 + 200 + 345')
#      13     print('100 + 200 + 345 =', r)
# ---> 14     r = calc('99 + 88 + 7.6')
#      15     print('99 + 88 + 7.6 =', r)
#      16
#
# <ipython-input-14-74ce84318ba9> in calc(exp)
#       7     ss = exp.split('+')
#       8     ns = map(str2num, ss)
# ----> 9     return reduce(lambda acc, x: acc + x, ns)
#      10
#      11 def main():
#
# <ipython-input-14-74ce84318ba9> in str2num(s)
#       2
#       3 def str2num(s):
# ----> 4     return int(s)
#       5
#       6 def calc(exp):
#
# ValueError: invalid literal for int() with base 10: ' 7.6'

# %% [markdown]
# ### 6、文件处理
# open()/write()/read()/close()
#
# os.rename()/os.remove()

# %%
#打开文件

# %%
#在文件中读写

# %%
#关闭文件

# %%
#打开文件

# %%
#读写文件

# %%
#文件更名

# %%
#删除文件
